# %% [markdown]
# # BERTScore
#
# BERTScore's evaluation architecture is designed to evaluate the quality of generated text by
# comparing it to a reference text. The architecture is built around several key components:
#
# ![bertscore.JPG](data:image/jpeg;base64,...)
# * Token Representation: BERTScore uses pre-trained BERT embeddings to represent tokens (words or subwords) in the text. These embeddings capture the semantic meaning of the tokens in their context 1.
#
# * Cosine Similarity: After obtaining the embeddings, BERTScore calculates the cosine similarity between the embeddings of the tokens in the generated text and the reference text. This gives a measure of how semantically similar the generated text is to the reference text 1.
#
# * Precision, Recall, and F1 Score: Each token in the reference sentence is matched to the most similar token in the generated sentence, and vice versa. This process is used to calculate the precision, recall, and F1 score, which are measures of the quality of the generated text 1.
#
# * Importance Weighting (Optional): This is an optional step in the BERTScore architecture. It assigns different weights to different tokens based on their importance. Tokens that are more likely to be important in the context of the text receive higher weights 1.
#
# * Baseline Rescaling: This is another optional step. It adjusts the BERTScore values to make them more human-readable. This is done by rescaling the scores with baseline scores 3.

# %%
# Install the package
# !pip install bert-score
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 2.8 MB/s eta 0:00:00
# ...

# %%
# Import the necessary libraries
from bert_score import BERTScorer

# Initialize the BERTScorer object
scorer = BERTScorer(lang='ru')

# Define the reference and candidate sentences
reference = ["Внедрение искусственного интеллекта в HR стоит начать с разработки стратегии."]
candidate = ["Для начала внедрения искусственного интеллекта в HR следует определить задачи, которые требуется решить, договориться об образе результата с бизнесом, оценить применимость технологий ИИ для достижения этого образа и сформулировать эффекты, которые принесет решение. Если экономика позволяет, можно смело делать шаг вперед."]

# Compute the BERTScore
P, R, F1 = scorer.score(candidate, reference)

# Print the scores
print("Precision: {:.2f}, Recall: {:.2f}, F1: {:.2f}".format(P.item(), R.item(), F1.item()))
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/482 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# ...

# %%
# Initialize the BERTScorer object
scorer = BERTScorer(lang='ru')

# Define the reference and candidate sentences
reference = ["Внедрение искусственного интеллекта в HR стоит начать с разработки стратегии.",
             "Искусственный интеллект (ИИ) представляет собой область компьютерных наук, которая занимается созданием программ и систем, способных имитировать человеческий интеллект и выполнять задачи, требующие когнитивного анализа разнородной информации. В том числе ИИ может использоваться для работы связанной с управлением персоналом.",
             "Совместная  работа нескольких пользователей упрощается с помощью напоминаний и подсказок.",
             "ИИ помогает автоматизировать и оптимизировать процессы подбора кандидатов на этапе анализа резюме, проведения интервью и принятия решения о найме.",
             "Утечка информации о сотрудниках может привести к серьезным последствиям для компании, включая ущерб репутации, юридические проблемы и потерю доверия со стороны сотрудников.",
             "Введение стандартизированных форматов и процедур для сбора и хранения данных о персонале может улучшить их качество и согласованность.",
             "Предвзятость может возникать из-за недостаточного или несбалансированного представления данных, использования неадекватных признаков или алгоритмов, а также из-за неправильного обучения моделей.",
             "После завершения пилотного проекта необходимо проанализировать его влияние на ключевые бизнес-показатели HR. Если результаты пилота оказываются успешными и соответствуют ожиданиям, можно приступать к масштабированию решения. В случае обнаружения проблем или несоответствия ожиданиям, необходимо проанализировать причины и внести коррективы для оптимизации эффективности.",
             "Сотрудничество со стартапами и исследовательскими организациями, ориентированными на ИИ, также может стать эффективным способом стимулирования инноваций в организации.",
             "HR-специалистам потребуются следующие навыки: создание оптимальных запросов для взаимодействия с моделями ИИ;  критическая оценка результатов работы моделей ИИ для принятия осознанных решений на основе данных; гибкость при встраивании моделей ИИ в свои задачи и готовность работать по-новому."
             ]
candidate1 = ["Для начала необходимо определить цели и задачи, которые будут решаться с помощью искусственного интеллекта в HR. Затем следует провести анализ текущих процессов и определить те области, где использование ИИ может быть наиболее эффективным. После этого нужно выбрать подходящие инструменты и технологии ИИ, которые будут соответствовать целям и задачам. Важно также учитывать особенности организации и ее потребности.",
              "Искусственный интеллект (ИИ) представляет собой область компьютерных наук, которая занимается созданием программ и систем, способных имитировать человеческий интеллект и выполнять задачи, требующие когнитивного анализа разнородной информации. Целью развития ИИ является создание систем, способных работать в реальном мире, адаптироваться к новым ситуациям, учиться на опыте и взаимодействовать с людьми и другими системами с помощью естественного языка или других интерфейсов. Искусственный интеллект находит широкое применение в различных областях, включая медицину, финансы, автомобильную промышленность, робототехнику, образование и многое другое.",
              "Совместная работа нескольких пользователей упрощается с помощью напоминаний и подсказок, которые предоставляет ИИ.",
              "ИИ помогает автоматизировать и оптимизировать процессы подбора кандидатов на этапе анализа резюме, сортировки кандидатов, проведения предварительного скрининга и проведения интервью.",
              "Утечка данных о сотрудниках может привести к серьезным последствиям для компании, включая ущерб репутации, юридические проблемы и потерю доверия со стороны сотрудников.",
              "Инвестиции в инструменты и технологии для предварительной обработки и интеграции данных помогут обеспечить эффективное использование данных для работы ИИ.",
              "Предвзятость к результатам работы ИИ может возникать из-за недостаточного или несбалансированного представления данных, использования неадекватных признаков или алгоритмов, а также из-за неправильного обучения моделей.",
              "После завершения пилотного проекта необходимо проанализировать его готовность и потенциал для масштабирования, собрать отзывы пользователей, провести оценку бизнес-метрик и внести улучшения в ИИ-модель или продукт.",
              "Сотрудничество со стартапами и исследовательскими организациями, ориентированными на ИИ, может стать эффективным способом стимулирования инноваций в организации.",
              "HR-специалистам потребуются следующие навыки для работы с ИИ: создание оптимальных запросов для взаимодействия с моделями ИИ, критическая оценка результатов работы моделей ИИ для принятия осознанных решений на основе данных и гибкость при встраивании моделей ИИ в свои задачи и готовность работать по-новому."
              ]
candidate2 =["Для начала внедрения искусственного интеллекта в HR следует определить задачи, которые требуется решить, договориться об образе результата с бизнесом, оценить применимость технологий ИИ для достижения этого образа и сформулировать эффекты, которые принесет решение. Если экономика позволяет, можно смело делать шаг вперед.",
             "Искусственный интеллект (ИИ) - это ряд технологических решений, имитирующих когнитивную деятельность человека, которые могут использоваться в различных областях, включая управление персоналом.",
             "Информация недостаточно для ответа на этот вопрос.",
             "ИИ помогает автоматизировать и оптимизировать процессы подбора кандидатов на этапе первичного отбора.",
             "Утечка данных о сотрудниках может привести к серьезным последствиям для компании, включая ущерб репутации, юридические проблемы и потерю доверия со стороны сотрудников.",
             "Инструменты автоматической очистки и стандартизации данных позволят повысить качество и надежность данных для использования в анализе и моделировании ИИ.",
             "Предвзятость к результатам работы ИИ может возникать из-за недостаточного или несбалансированного представления данных, использования неадекватных признаков или алгоритмов, а также из-за неправильного обучения моделей.",
             "После завершения пилотного проекта необходимо проанализировать его готовность и потенциал для масштабирования. Для этого нужно определить последовательность шагов, ресурсы, необходимые для масштабирования, и оценить возможные риски.",
             "Информация недостаточно для ответа на этот вопрос.",
             "HR-специалистам потребуются следующие навыки для работы с ИИ: создание оптимальных запросов для взаимодействия с моделями ИИ, критическая оценка результатов работы моделей ИИ для принятия осознанных решений на основе данных, гибкость при встраивании моделей ИИ в свои задачи и готовность работать по-новому."
             ]
candidate3 =["Для начала внедрения искусственного интеллекта в HR стоит начать с разработки стратегии, которая должна включать четкое определение областей и процессов в HR, где применение ИИ может повысить эффективность. Необходимо определить, какие HR-задачи будут решаться и каких целей достичь с помощью ИИ.",
             "Искусственный интеллект (ИИ) представляет собой ряд технологических решений, имитирующих когнитивную деятельность человека и способных выполнять задачи, требующие когнитивного анализа разнородной информации. Он может использоваться в различных областях, включая управление персоналом.",
             "Совместная работа нескольких пользователей упрощается с помощью напоминаний и подсказок, которые предоставляет искусственный интеллект.",
             "ИИ помогает автоматизировать и оптимизировать процессы подбора кандидатов на этапе найма.",
             "Утечка данных о сотрудниках может привести к серьезным последствиям для компании, включая ущерб репутации, юридические проблемы и потерю доверия со стороны сотрудников.",
             "Более эффективно использовать данные для анализа и обучения моделей ИИ позволит стандартизация данных, введение стандартизированных форматов и процедур для сбора и хранения данных о персонале. Это улучшит качество и согласованность данных, что позволит более эффективно использовать данные для анализа и обучения моделей ИИ.",
             "Предвзятость к результатам работы ИИ может возникать из-за недостаточного или несбалансированного представления данных, использования неадекватных признаков или алгоритмов, а также из-за неправильного обучения моделей.",
             "После завершения пилотного проекта необходимо проанализировать его влияние на ключевые бизнес-показатели HR. Если результаты пилота оказываются успешными и соответствуют ожиданиям, можно приступать к масштабированию решения. В случае обнаружения проблем или несоответствия ожиданиям, необходимо проанализировать причины и внести коррективы для оптимизации эффективности.",
             "Эффективным способом стимулирования инноваций в организации может стать сотрудничество со стартапами и исследовательскими организациями, ориентированными на ИИ.",
             "HR-специалистам потребуются следующие навыки для работы с ИИ: создание оптимальных запросов для взаимодействия с моделями ИИ, критическая оценка результатов работы моделей ИИ для принятия осознанных решений на основе данных, гибкость при встраивании моделей ИИ в свои задачи и готовность работать по-новому."
             ]
candidate4 =["Внедрение искусственного интеллекта в HR  стоит начать с разработки стратегии.",
             "Искусственный интеллект (ИИ) представляет собой область компьютерных наук, которая занимается созданием программ и систем, способных имитировать человеческий интеллект и выполнять задачи, требующие когнитивного анализа разнородной информации. Целью развития ИИ является создание систем, способных работать в реальном мире, адаптироваться к новым ситуациям, учиться на опыте и взаимодействовать с людьми и другими системами с помощью естественного языка или других интерфейсов.",
             "ИИ может упрощать совместную работу нескольких пользователей с помощью напоминаний и подсказок.",
             "ИИ помогает автоматизировать и оптимизировать процессы подбора кандидатов на этапе анализа резюме, сортировки кандидатов, предварительного скрининга и проведения интервью.",
             "Утечка данных о сотрудниках может привести к серьезным последствиям для компании, включая ущерб репутации, юридические проблемы и потерю доверия со стороны сотрудников.",
             "Инвестиции в инструменты и технологии для предварительной обработки и интеграции данных позволят более эффективно использовать данные для анализа и обучения моделей ИИ.",
             "Предвзятость к результатам работы ИИ может возникать из-за недостаточного или несбалансированного представления данных, использования неадекватных признаков или алгоритмов, а также из-за неправильного обучения моделей.",
             "После завершения пилотного проекта необходимо проанализировать следующие аспекты: Оценку эффективности решения: сравнить результаты пилотного проекта с ожидаемыми результатами и определить, насколько успешно было достигнуто поставленных целей. Обратную связь от пользователей: собрать отзывы пользователей, участвовавших в пилотном проекте, чтобы выявить общие требования и замечания.Бизнес-метрики: проанализировать данные бизнес-метрики, такие как уровень удержания персонала, производительность и другие показатели, чтобы оценить влияние решения на бизнес-процессы. Масштабирование решения: оценить готовность решения к масштабированию, определить необходимые ресурсы и риски, связанные с расширением использования решения.",
             "Сотрудничество со стартапами и исследовательскими организациями, ориентированными на ИИ, может стать эффективным способом стимулирования инноваций в организации.",
             "HR-специалистам потребуются соответствующие знания и навыки для работы с ИИ. Необходимо иметь базовые знания о принципах работы искусственного интеллекта и его применении в управлении человеческими ресурсами. Также важны навыки анализа данных и умение работать с инструментами ИИ."
             ]
# Compute the BERTScore
P, R, F1 = scorer.score(candidate1, reference)
P1, R1, F11 = scorer.score(candidate2, reference)
P2, R2, F12 = scorer.score(candidate3, reference)
P3, R3, F13 = scorer.score(candidate4, reference)

# Print the scores
print("Precision: {:.2f}, Recall: {:.2f}, F1: {:.2f}".format(P.mean(), R.mean(), F1.mean()))
print("Precision: {:.2f}, Recall: {:.2f}, F1: {:.2f}".format(P1.mean(), R1.mean(), F11.mean()))
print("Precision: {:.2f}, Recall: {:.2f}, F1: {:.2f}".format(P2.mean(), R2.mean(), F12.mean()))
print("Precision: {:.2f}, Recall: {:.2f}, F1: {:.2f}".format(P3.mean(), R3.mean(), F13.mean()))
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Precision: 0.87, Recall: 0.90, F1: 0.88
# Precision: 0.82, Recall: 0.81, F1: 0.81
# Precision: 0.90, Recall: 0.94, F1: 0.92
# Precision: 0.88, Recall: 0.89, F1: 0.89

# %%
Для начала необходимо определить цели и задачи, которые будут решаться с помощью искусственного интеллекта в HR. Затем следует провести анализ текущих процессов и определить те области, где использование ИИ может быть наиболее эффективным. После этого нужно выбрать подходящие инструменты и технологии ИИ, которые будут соответствовать целям и задачам. Важно также учитывать особенности организации и ее потребности.
-----------------
Для начала внедрения искусственного интеллекта в HR следует определить задачи, которые требуется решить, договориться об образе результата с бизнесом, оценить применимость технологий ИИ для достижения этого образа и сформулировать эффекты, которые принесет решение. Если экономика позволяет, можно смело делать шаг вперед.
-----------------
Для начала внедрения искусственного интеллекта в HR стоит начать с разработки стратегии, которая должна включать четкое определение областей и процессов в HR, где применение ИИ может повысить эффективность. Необходимо определить, какие HR-задачи будут решаться и каких целей достичь с помощью ИИ.
-----------------
Внедрение искусственного интеллекта в HR  стоит начать с разработки стратегии.

вопрос №2
Искусственный интеллект (ИИ) представляет собой область компьютерных наук, которая занимается созданием программ и систем, способных имитировать человеческий интеллект и выполнять задачи, требующие когнитивного анализа разнородной информации. Целью развития ИИ является создание систем, способных работать в реальном мире, адаптироваться к новым ситуациям, учиться на опыте и взаимодействовать с людьми и другими системами с помощью естественного языка или других интерфейсов. Искусственный интеллект находит широкое применение в различных областях, включая медицину, финансы, автомобильную промышленность, робототехнику, образование и многое другое.
-----------------
Искусственный интеллект (ИИ) - это ряд технологических решений, имитирующих когнитивную деятельность человека, которые могут использоваться в различных областях, включая управление персоналом.
-----------------
Искусственный интеллект (ИИ) представляет собой ряд технологических решений, имитирующих когнитивную деятельность человека и способных выполнять задачи, требующие когнитивного
анализа разнородной информации. Он может использоваться в различных областях, включая управление персоналом.
-----------------
Искусственный интеллект (ИИ) представляет собой область компьютерных наук, которая занимается созданием программ и систем, способных имитировать человеческий интеллект и выполнять задачи, требующие когнитивного анализа разнородной информации. Целью развития ИИ является создание систем, способных работать в реальном мире, адаптироваться к новым ситуациям, учиться на опыте и взаимодействовать с людьми и другими системами с помощью естественного языка или других интерфейсов.
вопрос №3
Совместная работа нескольких пользователей упрощается с помощью напоминаний и подсказок, которые предоставляет ИИ.
-----------------
Информация недостаточно для ответа на этот вопрос.
-----------------
Совместная работа нескольких пользователей упрощается с помощью напоминаний и подсказок, которые предоставляет искусственный интеллект.
-----------------
 ИИ может упрощать совместную работу нескольких пользователей с помощью напоминаний и подсказок.
вопрос №4
ИИ помогает автоматизировать и оптимизировать процессы подбора кандидатов на этапе анализа резюме, сортировки кандидатов, проведения предварительного скрининга и проведения интервью.
-----------------
ИИ помогает автоматизировать и оптимизировать процессы подбора кандидатов на этапе первичного отбора.
-----------------
ИИ помогает автоматизировать и оптимизировать процессы подбора кандидатов на этапе найма.
-----------------
ИИ помогает автоматизировать и оптимизировать процессы подбора кандидатов на этапе анализа резюме, сортировки кандидатов, предварительного скрининга и проведения интервью.


вопрос №5
Утечка данных о сотрудниках может привести к серьезным последствиям для компании, включая ущерб репутации, юридические проблемы и потерю доверия со стороны сотрудников.
-----------------
Утечка данных о сотрудниках может привести к серьезным последствиям для компании, включая ущерб репутации, юридические проблемы и потерю доверия со стороны сотрудников.
-----------------
Утечка данных о сотрудниках может привести к серьезным последствиям для компании, включая ущерб репутации, юридические проблемы и потерю доверия со стороны сотрудников.
-----------------
Утечка данных о сотрудниках может привести к серьезным последствиям для компании, включая ущерб репутации, юридические проблемы и потерю доверия со стороны сотрудников.
вопрос №6
Инвестиции в инструменты и технологии для предварительной обработки и интеграции данных помогут обеспечить эффективное использование данных для работы ИИ.
-----------------
Инструменты автоматической очистки и стандартизации данных позволят повысить качество и надежность данных для использования в анализе и моделировании ИИ.
-----------------
Более эффективно использовать данные для анализа и обучения моделей ИИ позволит стандартизация данных, введение стандартизированных форматов и процедур для сбора и хранения данных о персонале. Это улучшит качество и согласованность данных, что позволит более эффективно использовать данные для анализа и обучения моделей ИИ.
-----------------
Инвестиции в инструменты и технологии для предварительной обработки и интеграции данных позволят более эффективно использовать данные для анализа и обучения моделей ИИ.
вопрос №7
Предвзятость к результатам работы ИИ может возникать из-за недостаточного или несбалансированного представления данных, использования неадекватных признаков или алгоритмов, а также из-за неправильного обучения моделей.
-----------------
Предвзятость к результатам работы ИИ может возникать из-за недостаточного или несбалансированного представления данных, использования неадекватных признаков или алгоритмов, а также из-за неправильного обучения моделей.
-----------------
Предвзятость к результатам работы ИИ может возникать из-за недостаточного или несбалансированного представления данных, использования неадекватных признаков или алгоритмов, а также из-за неправильного обучения моделей.
-----------------
Предвзятость к результатам работы ИИ может возникать из-за недостаточного или несбалансированного представления данных, использования неадекватных признаков или алгоритмов, а также из-за неправильного обучения моделей.
вопрос №8
После завершения пилотного проекта необходимо проанализировать его готовность и потенциал для масштабирования, собрать отзывы пользователей, провести оценку бизнес-метрик и внести улучшения в ИИ-модель или продукт.
-----------------
После завершения пилотного проекта необходимо проанализировать его готовность и потенциал для масштабирования. Для этого нужно определить последовательность шагов, ресурсы, необходимые для масштабирования, и оценить возможные риски.
-----------------
После завершения пилотного проекта необходимо проанализировать его влияние на ключевые бизнес-показатели HR. Если результаты пилота оказываются успешными и соответствуют ожиданиям, можно приступать к масштабированию решения. В случае обнаружения проблем или несоответствия ожиданиям, необходимо проанализировать причины и внести коррективы для оптимизации эффективности.
-----------------
После завершения пилотного проекта необходимо проанализировать следующие аспекты:
- Оценку эффективности решения: сравнить результаты пилотного проекта с ожидаемыми результатами и определить, насколько успешно было достигнуто поставленных целей.
- Обратную связь от пользователей: собрать отзывы пользователей, участвовавших в пилотном проекте, чтобы выявить общие требования и замечания.
- Бизнес-метрики: проанализировать данные бизнес-метрики, такие как уровень удержания персонала, производительность и другие показатели, чтобы оценить влияние решения на бизнес-процессы.
- Масштабирование решения: оценить готовность решения к масштабированию, определить необходимые ресурсы и риски, связанные с расширением использования решения.

вопрос №9
Сотрудничество со стартапами и исследовательскими организациями, ориентированными на ИИ, может стать эффективным способом стимулирования инноваций в организации.
-----------------
Информация о способах стимулирования инноваций в организации отсутствует в данном контексте.
-----------------
Эффективным способом стимулирования инноваций в организации может стать сотрудничество со стартапами и исследовательскими организациями, ориентированными на ИИ.
-----------------
Сотрудничество со стартапами и исследовательскими организациями, ориентированными на ИИ, может стать эффективным способом стимулирования инноваций в организации.
вопрос №10
HR-специалистам потребуются следующие навыки для работы с ИИ: создание оптимальных запросов для взаимодействия с моделями ИИ, критическая оценка результатов работы моделей ИИ для принятия осознанных решений на основе данных и гибкость при встраивании моделей ИИ в свои задачи и готовность работать по-новому.
-----------------
HR-специалистам потребуются следующие навыки для работы с ИИ: создание оптимальных запросов для взаимодействия с моделями ИИ, критическая оценка результатов работы моделей ИИ для принятия осознанных решений на основе данных, гибкость при встраивании моделей ИИ в свои задачи и готовность работать по-новому.
-----------------
HR-специалистам потребуются следующие навыки для работы с ИИ: создание оптимальных запросов для взаимодействия с моделями ИИ, критическая оценка результатов работы моделей ИИ для принятия осознанных решений на основе данных, гибкость при встраивании моделей ИИ в свои задачи и готовность работать по-новому.
-----------------
HR-специалистам потребуются соответствующие знания и навыки для работы с ИИ.
Необходимо иметь базовые знания о принципах работы искусственного интеллекта и его применении в управлении человеческими ресурсами.
Также важны навыки анализа данных и умение работать с инструментами ИИ.
